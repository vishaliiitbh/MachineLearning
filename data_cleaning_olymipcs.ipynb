# %%
import pandas as pd
import numpy as ny
data=pd.read_csv("Olympic_Swimming_Results_1912to2020.csv")

# %%
data.head()
# Out:
#   Location  Year Distance (in meters)      Stroke  Relay? Gender Team  \
# 0    Tokyo  2020                 100m  Backstroke       0    Men  ROC
# 1    Tokyo  2020                 100m  Backstroke       0    Men  ROC
# 2    Tokyo  2020                 100m  Backstroke       0    Men  USA
# 3    Tokyo  2020                 100m  Backstroke       0    Men  ITA
# 4    Tokyo  2020                 100m  Backstroke       0    Men  CHN
#
#               Athlete Results  Rank
# 0        Evgeny Rylov   51.98     1
# 1  Kliment Kolesnikov      52     2
# 2         Ryan Murphy   52.19     3
# 3       Thomas Ceccon    52.3     4
# 4            Jiayu Xu   52.51     4

# %%
data["Relay?"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data["Stroke"].unique()
# Out:
# array(['Backstroke', 'Breaststroke', 'Butterfly', 'Freestyle',
#        'Individual medley', 'Medley'], dtype=object)

# %%
new_d=data.replace({'Distance (in meters)':'[A-Za-z]'},'',regex=True)

# %%
new_d
# Out:
#        Location  Year Distance (in meters)      Stroke  Relay? Gender Team  \
# 0         Tokyo  2020                  100  Backstroke       0    Men  ROC
# 1         Tokyo  2020                  100  Backstroke       0    Men  ROC
# 2         Tokyo  2020                  100  Backstroke       0    Men  USA
# 3         Tokyo  2020                  100  Backstroke       0    Men  ITA
# 4         Tokyo  2020                  100  Backstroke       0    Men  CHN
# ...         ...   ...                  ...         ...     ...    ...  ...
# 4354  Stockholm  1912                 4100   Freestyle       1  Women  SWE
# 4355  Stockholm  1912                 4200   Freestyle       1    Men  AUS
# 4356  Stockholm  1912                 4200   Freestyle       1    Men  USA
# 4357  Stockholm  1912                 4200   Freestyle       1    Men  GBR
# 4358  Stockholm  1912                 4200   Freestyle       1    Men  GER
#
# ...

# %%
new_d.dtypes
# Out:
# Location                object
# Year                     int64
# Distance (in meters)    object
# Stroke                  object
# Relay?                   int64
# Gender                  object
# Team                    object
# Athlete                 object
# Results                 object
# Rank                     int64
# dtype: object

# %%
backs=new_d[new_d.Stroke=='Backstroke']

# %%
data.dropna()
# Out:
#        Location  Year Distance (in meters)      Stroke  Relay? Gender Team  \
# 0         Tokyo  2020                 100m  Backstroke       0    Men  ROC
# 1         Tokyo  2020                 100m  Backstroke       0    Men  ROC
# 2         Tokyo  2020                 100m  Backstroke       0    Men  USA
# 3         Tokyo  2020                 100m  Backstroke       0    Men  ITA
# 4         Tokyo  2020                 100m  Backstroke       0    Men  CHN
# ...         ...   ...                  ...         ...     ...    ...  ...
# 4353  Stockholm  1912                4x100   Freestyle       1  Women  AUT
# 4355  Stockholm  1912                4x200   Freestyle       1    Men  AUS
# 4356  Stockholm  1912                4x200   Freestyle       1    Men  USA
# 4357  Stockholm  1912                4x200   Freestyle       1    Men  GBR
# 4358  Stockholm  1912                4x200   Freestyle       1    Men  GER
#
# ...

# %%
backs.dropna()
# Out:
#        Location  Year Distance (in meters)      Stroke  Relay? Gender Team  \
# 0         Tokyo  2020                  100  Backstroke       0    Men  ROC
# 1         Tokyo  2020                  100  Backstroke       0    Men  ROC
# 2         Tokyo  2020                  100  Backstroke       0    Men  USA
# 3         Tokyo  2020                  100  Backstroke       0    Men  ITA
# 4         Tokyo  2020                  100  Backstroke       0    Men  CHN
# ...         ...   ...                  ...         ...     ...    ...  ...
# 4299  Stockholm  1912                  100  Backstroke       0    Men  HUN
# 4300  Stockholm  1912                  100  Backstroke       0    Men  GER
# 4301  Stockholm  1912                  100  Backstroke       0    Men  GER
# 4302  Stockholm  1912                  100  Backstroke       0    Men  HUN
# 4303  Stockholm  1912                  100  Backstroke       0    Men  BEL
#
#                  Athlete          Results  Rank
# ...

# %%
new_d=data.replace({'Results':'[A-Za-z]'},'',regex=True)

# %%
new_d
# Out:
#        Location  Year Distance (in meters)      Stroke  Relay? Gender Team  \
# 0         Tokyo  2020                 100m  Backstroke       0    Men  ROC
# 1         Tokyo  2020                 100m  Backstroke       0    Men  ROC
# 2         Tokyo  2020                 100m  Backstroke       0    Men  USA
# 3         Tokyo  2020                 100m  Backstroke       0    Men  ITA
# 4         Tokyo  2020                 100m  Backstroke       0    Men  CHN
# ...         ...   ...                  ...         ...     ...    ...  ...
# 4354  Stockholm  1912                4x100   Freestyle       1  Women  SWE
# 4355  Stockholm  1912                4x200   Freestyle       1    Men  AUS
# 4356  Stockholm  1912                4x200   Freestyle       1    Men  USA
# 4357  Stockholm  1912                4x200   Freestyle       1    Men  GBR
# 4358  Stockholm  1912                4x200   Freestyle       1    Men  GER
#
# ...

# %%
type(data['Results'][0])
# Out:
# str

# %%
type(new_d['Results'][4357])
# Out:
# str

# %%
len(new_d['Results'][4357])
# Out:
# 15

# %%
time_result=new_d['Results'].apply(lambda x: type(x)==str)

# %%
time_result
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 4354    False
# 4355     True
# 4356     True
# 4357     True
# 4358     True
# Name: Results, Length: 4359, dtype: bool

# %%
new_d.dropna()
# Out:
#        Location  Year Distance (in meters)      Stroke  Relay? Gender Team  \
# 0         Tokyo  2020                 100m  Backstroke       0    Men  ROC
# 1         Tokyo  2020                 100m  Backstroke       0    Men  ROC
# 2         Tokyo  2020                 100m  Backstroke       0    Men  USA
# 3         Tokyo  2020                 100m  Backstroke       0    Men  ITA
# 4         Tokyo  2020                 100m  Backstroke       0    Men  CHN
# ...         ...   ...                  ...         ...     ...    ...  ...
# 4353  Stockholm  1912                4x100   Freestyle       1  Women  AUT
# 4355  Stockholm  1912                4x200   Freestyle       1    Men  AUS
# 4356  Stockholm  1912                4x200   Freestyle       1    Men  USA
# 4357  Stockholm  1912                4x200   Freestyle       1    Men  GBR
# 4358  Stockholm  1912                4x200   Freestyle       1    Men  GER
#
# ...

# %%
new_d
# Out:
#        Location  Year Distance (in meters)      Stroke  Relay? Gender Team  \
# 0         Tokyo  2020                 100m  Backstroke       0    Men  ROC
# 1         Tokyo  2020                 100m  Backstroke       0    Men  ROC
# 2         Tokyo  2020                 100m  Backstroke       0    Men  USA
# 3         Tokyo  2020                 100m  Backstroke       0    Men  ITA
# 4         Tokyo  2020                 100m  Backstroke       0    Men  CHN
# ...         ...   ...                  ...         ...     ...    ...  ...
# 4354  Stockholm  1912                4x100   Freestyle       1  Women  SWE
# 4355  Stockholm  1912                4x200   Freestyle       1    Men  AUS
# 4356  Stockholm  1912                4x200   Freestyle       1    Men  USA
# 4357  Stockholm  1912                4x200   Freestyle       1    Men  GBR
# 4358  Stockholm  1912                4x200   Freestyle       1    Men  GER
#
# ...

# %%
type(new_d['number'][0])
# Out:
# str

# %%
new_d['number'] = pd.to_numeric(new_d['Results'], errors='coerce')

# %%
new_d
# Out:
#        Location  Year Distance (in meters)      Stroke  Relay? Gender Team  \
# 0         Tokyo  2020                 100m  Backstroke       0    Men  ROC
# 1         Tokyo  2020                 100m  Backstroke       0    Men  ROC
# 2         Tokyo  2020                 100m  Backstroke       0    Men  USA
# 3         Tokyo  2020                 100m  Backstroke       0    Men  ITA
# 4         Tokyo  2020                 100m  Backstroke       0    Men  CHN
# ...         ...   ...                  ...         ...     ...    ...  ...
# 4354  Stockholm  1912                4x100   Freestyle       1  Women  SWE
# 4355  Stockholm  1912                4x200   Freestyle       1    Men  AUS
# 4356  Stockholm  1912                4x200   Freestyle       1    Men  USA
# 4357  Stockholm  1912                4x200   Freestyle       1    Men  GBR
# 4358  Stockholm  1912                4x200   Freestyle       1    Men  GER
#
# ...

# %%
nums=new_d.dropna()

# %%
nums
# Out:
#        Location  Year Distance (in meters)      Stroke  Relay? Gender Team  \
# 0         Tokyo  2020                 100m  Backstroke       0    Men  ROC
# 1         Tokyo  2020                 100m  Backstroke       0    Men  ROC
# 2         Tokyo  2020                 100m  Backstroke       0    Men  USA
# 3         Tokyo  2020                 100m  Backstroke       0    Men  ITA
# 4         Tokyo  2020                 100m  Backstroke       0    Men  CHN
# ...         ...   ...                  ...         ...     ...    ...  ...
# 4019    Angeles  1932                 100m   Freestyle       0    Men  JPN
# 4020    Angeles  1932                 100m   Freestyle       0    Men  USA
# 4091  Amsterdam  1928                 100m   Freestyle       0    Men  USA
# 4092  Amsterdam  1928                 100m   Freestyle       0    Men  HUN
# 4174      Paris  1924                 100m   Freestyle       0    Men  USA
#
#                         Athlete Results  Rank string  number
# ...

# %%
nums.drop(['string','Results'],axis=1)
# Out:
#        Location  Year Distance (in meters)      Stroke  Relay? Gender Team  \
# 0         Tokyo  2020                 100m  Backstroke       0    Men  ROC
# 1         Tokyo  2020                 100m  Backstroke       0    Men  ROC
# 2         Tokyo  2020                 100m  Backstroke       0    Men  USA
# 3         Tokyo  2020                 100m  Backstroke       0    Men  ITA
# 4         Tokyo  2020                 100m  Backstroke       0    Men  CHN
# ...         ...   ...                  ...         ...     ...    ...  ...
# 4019    Angeles  1932                 100m   Freestyle       0    Men  JPN
# 4020    Angeles  1932                 100m   Freestyle       0    Men  USA
# 4091  Amsterdam  1928                 100m   Freestyle       0    Men  USA
# 4092  Amsterdam  1928                 100m   Freestyle       0    Men  HUN
# 4174      Paris  1924                 100m   Freestyle       0    Men  USA
#
#                         Athlete  Rank  number
# ...
